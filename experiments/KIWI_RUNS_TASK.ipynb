# %% [markdown]
# # Small Example what a Task Object can do

# %%
# some setup code
# %config InteractiveShell.ast_node_interactivity='last_expr_or_assign'  # always print last expr.
# %config InlineBackend.figure_format = 'svg'
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

import logging

logging.basicConfig(level=logging.INFO)

# %%
from tsdm.tasks import KIWI_RUNS_TASK
# Out:
# INFO:numexpr.utils:Note: NumExpr detected 24 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# INFO:numexpr.utils:NumExpr defaulting to 8 threads.
# INFO:tsdm.config._config:Available Models: {'BRITS', 'TFT', 'NCDE', 'TPA', 'GRU-ODE-Bayes', 'ODE-RNN', 'mTAN', 'N-BEATS', 'Informer', 'M-RNN', 'Latent-ODE', 'SET-TS', 'NODE', 'IP-Net'}
# INFO:tsdm.config._config:Available Datasets: {'Air Quality', 'USHCN', 'Traffic', 'M3', 'Physionet 2012', 'Human Activity', 'Physionet 2019', 'tourism2', 'UWAVE', 'Electricity', 'tourism1', 'Air Quality Multi-Site', 'MuJoCo', 'Household Consumption', 'Character Trajectories', 'M4', 'M5'}
# INFO:tsdm.config._config:Initializing folder structure
# INFO:tsdm.config._config:creating folder /home/rscholz/.tsdm/datasets
# INFO:tsdm.config._config:creating folder /home/rscholz/.tsdm/models
# INFO:tsdm.config._config:creating folder /home/rscholz/.tsdm/logs
# INFO:tsdm.config._config:creating folder /home/rscholz/.tsdm/rawdata
# INFO:tsdm.config._config:Created folder structure in /home/rscholz/.tsdm

# %%
task = KIWI_RUNS_TASK()
# Out:
# INFO:tsdm.datasets.base._base:KIWI_RUNS: START cleaning dataset!
# INFO:tsdm.datasets.base._base:KIWI_RUNS/timeseries already exists, skipping.
# INFO:tsdm.datasets.base._base:KIWI_RUNS/metadata already exists, skipping.
# INFO:tsdm.datasets.base._base:KIWI_RUNS/units already exists, skipping.
# INFO:tsdm.datasets.base._base:KIWI_RUNS: DONE cleaning dataset
# INFO:tsdm.datasets.base._base:KIWI_RUNS: START loading dataset!
# INFO:tsdm.datasets.base._base:KIWI_RUNS/timeseries: START loading dataset!
# INFO:tsdm.datasets.base._base:KIWI_RUNS/timeseries: DONE loading dataset!
# INFO:tsdm.datasets.base._base:KIWI_RUNS/metadata: START loading dataset!
# INFO:tsdm.datasets.base._base:KIWI_RUNS/metadata: DONE loading dataset!
# INFO:tsdm.datasets.base._base:KIWI_RUNS/units: START loading dataset!
# INFO:tsdm.datasets.base._base:KIWI_RUNS/units: DONE loading dataset!
# INFO:tsdm.datasets.base._base:KIWI_RUNS: DONE loading dataset!
# KIWI_RUNS_TASK(dataset=KIWI_RUNS, test_metric=WRMSE)

# %% [markdown]
# ### Attributes and Methods

# %% [markdown]
# ## Note: The .dataset attribute contains the **original** dataset without any task-specific modifications.

# %%
task.dataset
# Out:
# KIWI_RUNS['timeseries', 'metadata', 'units']

# %% [markdown]
# Whereas the **`.timeseries`** **`.metadata`** and **`.unit`** attributes contain the task-specific preprocessed versions of these datasets

# %%
assert 355 in task.dataset.timeseries.index
assert 355 not in task.index
task.timeseries
# Out:
# variable                                  Flow_Air  StirringSpeed  \
# run_id experiment_id measurement_time
# 439    15325         2020-12-09 09:10:09       0.0            0.0
#                      2020-12-09 09:10:19       0.0            0.0
#                      2020-12-09 09:10:24       0.0          100.0
#                      2020-12-09 09:10:24           0.0      <NA>      <NA>
#                      2020-12-09 09:10:25           0.0      <NA>      <NA>
#                      2020-12-09 09:10:34           0.0      7.28      <NA>
# ...                                                ...       ...       ...
# 510    16871         2021-10-26 22:41:26        5500.0      <NA>      <NA>
#                      2021-10-26 22:42:11        5500.0      <NA>      <NA>
#                      2021-10-26 22:42:20        5500.0  7.320229      <NA>
#                      2021-10-26 22:43:22        5500.0      <NA>      <NA>
#                      2021-10-26 22:43:31        5500.0  7.336412      <NA>
#
# variable                                  InducerConcentration      Volume
# run_id experiment_id measurement_time
# 439    15325         2020-12-09 09:10:09                   0.0        <NA>
#                      2020-12-09 09:10:19                   0.0        <NA>
#                      2020-12-09 09:10:24                   0.0        <NA>
#                      2020-12-09 09:10:25                   0.0        <NA>
#                      2020-12-09 09:10:34                   0.0        <NA>
# ...                                                        ...         ...
# 510    16871         2021-10-26 22:41:26                   0.0 -312.692749
#                      2021-10-26 22:42:11                   0.0        <NA>
#                      2021-10-26 22:42:20                   0.0        <NA>
#                      2021-10-26 22:43:22                   0.0        <NA>
#                      2021-10-26 22:43:31                   0.0        <NA>
#
# [324957 rows x 15 columns]

# %% [markdown]
# The attributes `.split`, `.split_idx` contain information about the splits

# %%
task.split_idx
# Out:
# split                     0      1      2      3      4
# run_id experiment_id
# 439    15325          train  train  train  train  train
#        15326          train  train  train  train  train
#        15327          train   test  train  train  train
#        15328          train  train   test   test  train
#        15329          train  train  train  train  train
# ...                     ...    ...    ...    ...    ...
# 510    16867          train  train   test  train  train
#        16868          train   test  train  train   test
#        16869          train  train  train  train  train
#        16870          train   test  train  train   test
#        16871          train  train   test  train   test
#
# [216 rows x 5 columns]

# %% [markdown]
# ### `.batchloaders` and `.datalaoders` are lazily loaded dictionaries

# %%
task.dataloaders
# Out:
# LazyDict(
#   (0, 'train'): <LazyFunction: get_dataloader>
#   (0, 'test') : <LazyFunction: get_dataloader>
#   (1, 'train'): <LazyFunction: get_dataloader>
#   (1, 'test') : <LazyFunction: get_dataloader>
#   (2, 'train'): <LazyFunction: get_dataloader>
#   (2, 'test') : <LazyFunction: get_dataloader>
#   (3, 'train'): <LazyFunction: get_dataloader>
#   (3, 'test') : <LazyFunction: get_dataloader>
#   (4, 'train'): <LazyFunction: get_dataloader>
#   (4, 'test') : <LazyFunction: get_dataloader>
# )

# %%
dataloader = task.dataloaders[(2, "test")]

# %%
task.dataloaders
# Out:
# LazyDict(
#   (0, 'train'): <LazyFunction: get_dataloader>
#   (0, 'test') : <LazyFunction: get_dataloader>
#   (1, 'train'): <LazyFunction: get_dataloader>
#   (1, 'test') : <LazyFunction: get_dataloader>
#   (2, 'train'): <LazyFunction: get_dataloader>
#   (2, 'test') : <torch.utils.data.dataloader.DataLoader object at 0x7f5b3e1af1f0>
#   (3, 'train'): <LazyFunction: get_dataloader>
#   (3, 'test') : <LazyFunction: get_dataloader>
#   (4, 'train'): <LazyFunction: get_dataloader>
#   (4, 'test') : <LazyFunction: get_dataloader>
# )

# %% [markdown]
# ### Each dataloader has a **`.preprocessor`** attribute which is a copy of the task-specific preprocessor fitted on the training data corresponding on the selected split

# %%
dataloader.preprocessor
# Out:
# ChainedEncoder[TensorEncoder(), DataFrameEncoder(                                                                 col  \
# section partition
# index   0                                                       <NA>
# columns 0          [Flow_Air, StirringSpeed, Temperature, Acetate...
#
#                                                 encoder
# section partition
# index   0               (MinMaxScaler, DateTimeEncoder)
# columns 0          (Standardizer([-1]), FloatEncoder())
# )]

# %%
batch = next(iter(dataloader))
T, X = batch
T.shape, X.shape
# Out:
# (torch.Size([128, 120]), torch.Size([128, 120, 15]))

# %% [markdown]
# #### The preprocessor can be used to recover the original unencoded data. This does not work in batch-mode at the moment!

# %%
t, x = T[0], X[0]
t, x
# Out:
# (tensor([0.4105, 0.4105, 0.4105, 0.4106, 0.4106, 0.4106, 0.4106, 0.4106, 0.4106,
#          0.4106, 0.4106, 0.4106, 0.4106, 0.4106, 0.4106, 0.4106, 0.4106, 0.4106,
#          0.4106, 0.4106, 0.4106, 0.4106, 0.4106, 0.4106, 0.4106, 0.4106, 0.4106,
#          0.4106, 0.4106, 0.4106, 0.4106, 0.4106, 0.4106, 0.4106, 0.4106, 0.4106,
#          0.4106, 0.4106, 0.4106, 0.4106, 0.4106, 0.4106, 0.4106, 0.4106, 0.4106,
#          0.4106, 0.4106, 0.4106, 0.4106, 0.4106, 0.4106, 0.4106, 0.4106, 0.4106,
#          0.4106, 0.4106, 0.4106, 0.4106, 0.4106, 0.4106, 0.4106, 0.4106, 0.4106,
#          0.4106, 0.4106, 0.4106, 0.4106, 0.4106, 0.4106, 0.4106, 0.4106, 0.4106,
#          0.4106, 0.4106, 0.4106, 0.4106, 0.4106, 0.4106, 0.4106, 0.4106, 0.4106,
#          0.4106, 0.4106, 0.4106, 0.4106, 0.4106, 0.4106, 0.4107, 0.4107, 0.4107,
#          0.4107, 0.4107, 0.4107, 0.4107, 0.4107, 0.4107, 0.4107, 0.4107, 0.4107,
#          0.4107, 0.4107, 0.4107, 0.4107, 0.4107, 0.4107, 0.4107, 0.4107, 0.4107,
#          0.4107, 0.4107, 0.4107, 0.4107, 0.4107, 0.4107, 0.4107, 0.4107, 0.4107,
#          0.4107, 0.4107, 0.4107], device='cuda:0'),
#  tensor([[-2.9278,  2.2687,     nan,  ...,     nan, -0.4377,     nan],
#          [-0.3877,  2.2687,     nan,  ...,     nan, -0.4377,     nan],
#          [-0.3877,  2.2687,     nan,  ...,     nan, -0.4377,     nan],
#          ...,
#          [-0.3877, -0.4862,     nan,  ...,     nan, -0.4377,     nan],
#          [-0.3877, -0.4862,     nan,  ...,     nan, -0.4377,     nan],
#          [-0.3877, -0.4862,  0.5127,  ...,     nan, -0.4377,     nan]],
#         device='cuda:0'))

# %%
dataloader.preprocessor.decode((t, x))
# Out:
# s
#                      Flow_Air  StirringSpeed  Temperature  Acetate  Base  \
# measurement_time
# 2021-04-20 09:27:55       0.0         2600.0         <NA>     <NA>  <NA>
# 2021-04-20 09:28:07       5.0         2600.0         <NA>     <NA>  <NA>
# 2021-04-20 09:35:14       5.0         2600.0         <NA>     <NA>  <NA>
# 2021-04-20 09:39:27       5.0         2600.0         <NA>     <NA>  <NA>
