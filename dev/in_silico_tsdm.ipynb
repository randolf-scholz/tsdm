# %%
from tsdm.datasets import InSilicoData

# %%
InSilicoData.dataset
# Out:
# {'16130':            Biomass  Substrate  Acetate      DOTm  Product  Volume          Feed
#  time
#  0.000000       NaN        NaN      NaN       NaN      NaN    0.01  0.000000e+00
#  0.194722       NaN        NaN      NaN  0.960606      NaN     NaN  0.000000e+00
#  0.214444       NaN        NaN      NaN  0.968268      NaN     NaN  0.000000e+00
#  0.233889       NaN        NaN      NaN  0.951641      NaN     NaN  0.000000e+00
#  0.253611       NaN        NaN      NaN  0.958530      NaN     NaN  0.000000e+00
#  ...            ...        ...      ...       ...      ...     ...           ...
#  11.333333      NaN        NaN      NaN       NaN      NaN     NaN  3.070077e-13
#  11.500000      NaN        NaN      NaN       NaN      NaN     NaN  3.117035e-13
#  11.666667      NaN        NaN      NaN       NaN      NaN     NaN  3.150078e-13
#  11.833333      NaN        NaN      NaN       NaN      NaN     NaN  3.168840e-13
# ...
