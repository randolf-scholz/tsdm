# %%
from tsdm.datasets import Electricity, InSilicoData

# %%
list(InSilicoData.dataset.values())[0]
# Out:
#            Biomass  Substrate  Acetate      DOTm  Product  Volume  \
# time
# 0.000000       NaN        NaN      NaN       NaN      NaN    0.01
# 0.194722       NaN        NaN      NaN  0.960606      NaN     NaN
# 0.214444       NaN        NaN      NaN  0.968268      NaN     NaN
# 0.233889       NaN        NaN      NaN  0.951641      NaN     NaN
# 0.253611       NaN        NaN      NaN  0.958530      NaN     NaN
# ...            ...        ...      ...       ...      ...     ...
# 11.333333      NaN        NaN      NaN       NaN      NaN     NaN
# 11.500000      NaN        NaN      NaN       NaN      NaN     NaN
# 11.666667      NaN        NaN      NaN       NaN      NaN     NaN
# 11.833333      NaN        NaN      NaN       NaN      NaN     NaN
# 12.000000      NaN        NaN      NaN       NaN      NaN     NaN
#
#                    Feed
# time
# 0.000000   0.000000e+00
# 0.194722   0.000000e+00
# 0.214444   0.000000e+00
# 0.233889   0.000000e+00
# 0.253611   0.000000e+00
# ...
