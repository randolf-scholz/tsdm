# %% [markdown]
# # Title

# %%
# %config InteractiveShell.ast_node_interactivity='last_expr_or_assign'  # always print last expr.
# %config InlineBackend.figure_format = 'svg'
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

import logging
logging.basicConfig(level=logging.INFO)

# %%
import numpy as np
import matplotlib.pyplot as plt

np.set_printoptions(precision=4, floatmode='fixed', suppress=True)
rng = np.random.default_rng()

# %%
import pickle
from collections import namedtuple
from types import MethodType

class foo:
    def __init__(self, name: str, fields: list[str]) -> None:
        self.bar = namedtuple(name, fields, module=__qualname__)
        # self.tuple_cls.__qualname__ = f"{self.__class__.__name__}.name"
        # func = lambda: self.__class__.__name__ + str(id(self))
        # self.tuple_cls.__reduce__ = MethodType(func, self.tuple_cls)

# %%
obj = A("point", ["x", "y"])

# %%
pickle.dumps(obj)
# Out:
# ---------------------------------------------------------------------------
# PicklingError                             Traceback (most recent call last)
# Input In [57], in <module>
# ----> 1 pickle.dumps(obj)
#
# PicklingError: Can't pickle <class '__main__.point'>: attribute lookup point on __main__ failed

# %%
id(obj)
# Out:
# 140102899626576

# %%
obj.tuple_cls.__reduce__()
# Out:
# 'A140102899626576'

# %%
_sys_
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [48], in <module>
# ----> 1 _sys_
#
# NameError: name '_sys_' is not defined
