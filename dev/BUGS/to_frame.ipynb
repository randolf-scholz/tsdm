# %%
from IPython import *
from types import MethodType
import numpy as np
from pandas import DataFrame

df = DataFrame(np.random.randn(100, 100))
df.to_frame = MethodType(lambda self: self, df)

# %%
# %%timeit
df.to_frame()
# Out:
# 61.9 ns ± 0.416 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
# %%timeit
DataFrame(df)
# Out:
# 1.33 µs ± 2.82 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)
