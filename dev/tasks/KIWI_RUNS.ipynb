# %% [markdown]
# # KIWI_RUNS Task Object

# %%
# %config InteractiveShell.ast_node_interactivity='last_expr_or_assign'  # always print last expr.
# %config InlineBackend.figure_format = 'svg'
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
import pickle
import pandas
import pandas as pd
import numpy as np
from pandas import DataFrame, Series

pd.set_option("display.max_rows", 10)

# %%
import tsdm

ds = tsdm.datasets.KIWI_RUNS
# Out:
# tsdm.datasets.kiwi_runs.KIWI_RUNS

# %% [markdown]
# ## Stefan's splits

# %%
from cross_validate_kiwi_runs import ReplicateBasedSplitter, create_replicate_dict

with open(ds.rawdata_file, "rb") as f:
    experiments_per_run = pickle.load(f)

col_run_to_exp = dict(create_replicate_dict(experiments_per_run))

splitter = ReplicateBasedSplitter()

stefan_splits = []

for train_keys, test_keys in splitter.split(col_run_to_exp):
    stefan_splits.append((train_keys, test_keys))

stefan_splits
# Out:
# [([(474, 16110),
#    (474, 16118),
#    (474, 16126),
#    (474, 16106),
#    (474, 16114),
#    (474, 16122),
#    (474, 16109),
#    (474, 16117),
#    (474, 16125),
#    (510, 16855),
#    (510, 16863),
#    (510, 16871),
#    (482, 16282),
#    (482, 16290),
#    (482, 16298),
#    (445, 15494),
#    (445, 15502),
#    (445, 15510),
#    (445, 15518),
#    (445, 15524),
#    (445, 15526),
#    (445, 15534),
#    (445, 15540),
#    (482, 16287),
#    (482, 16295),
#    (482, 16303),
#    (482, 16289),
#    (482, 16297),
#    (482, 16305),
#    (355, 11728),
#    (355, 11736),
#    (355, 11744),
#    (482, 16283),
#    (482, 16291),
#    (482, 16299),
#    (510, 16849),
#    (510, 16857),
#    (510, 16865),
#    (355, 11726),
#    (355, 11734),
#    (355, 11742),
#    (468, 15997),
#    (468, 16005),
#    (468, 16013),
#    (475, 16136),
#    (475, 16144),
#    (475, 16152),
#    (449, 15649),
#    (449, 15657),
#    (449, 15665),
#    (439, 15328),
#    (439, 15336),
#    (439, 15344),
#    (475, 16134),
#    (475, 16142),
#    (475, 16150),
#    (449, 15644),
#    (449, 15652),
#    (449, 15660),
#    (439, 15327),
#    (439, 15335),
#    (439, 15343),
#    (468, 15995),
#    (468, 16003),
#    (468, 16011),
#    (474, 16111),
#    (474, 16119),
#    (474, 16127),
#    (482, 16288),
#    (482, 16296),
#    (482, 16304),
#    (355, 11723),
#    (355, 11731),
#    (355, 11739),
#    (468, 15996),
#    (468, 16004),
#    (468, 16012),
#    (484, 16334),
#    (484, 16342),
#    (484, 16350),
#    (439, 15331),
#    (439, 15339),
#    (439, 15347),
#    (475, 16137),
#    (475, 16145),
#    (475, 16153),
#    (445, 15496),
#    (445, 15504),
#    (445, 15508),
#    (445, 15512),
#    (445, 15516),
#    (445, 15520),
#    (445, 15528),
#    (445, 15536),
#    (449, 15650),
#    (449, 15658),
#    (449, 15666),
#    (449, 15645),
#    (449, 15653),
#    (449, 15661),
#    (468, 15999),
#    (468, 16007),
#    (468, 16015),
#    (445, 15495),
#    (445, 15503),
#    (445, 15507),
#    (445, 15511),
#    (445, 15519),
#    (445, 15527),
#    (445, 15535),
#    (445, 15539),
#    (355, 11722),
#                      2019-04-09 18:32:21          <NA>      <NA>      <NA>
#                      2019-04-09 18:32:22          <NA>      <NA>      <NA>
# ...                                                ...       ...       ...
# 510    16871         2021-10-26 22:41:26          <NA>      <NA>      <NA>
#                      2021-10-26 22:42:11          <NA>      <NA>      <NA>
#                      2021-10-26 22:42:20          <NA>  7.320229      <NA>
#                      2021-10-26 22:43:22          <NA>      <NA>      <NA>
#                      2021-10-26 22:43:31          <NA>  7.336412      <NA>
#
#                                           InducerConcentration  Volume
# run_id experiment_id measurement_time
# 355    11722         2019-04-09 18:32:12                  <NA>    <NA>
#                      2019-04-09 18:32:18                  <NA>    <NA>
#                      2019-04-09 18:32:19                  <NA>    <NA>
#                      2019-04-09 18:32:21                  <NA>    <NA>
#                      2019-04-09 18:32:22                  <NA>    <NA>
# ...                                                        ...     ...
# 510    16871         2021-10-26 22:41:26                  <NA>     0.0
#                      2021-10-26 22:42:11                  <NA>    <NA>
#                      2021-10-26 22:42:20                  <NA>    <NA>
#                      2021-10-26 22:43:22                  <NA>    <NA>
#                      2021-10-26 22:43:31                  <NA>    <NA>
#
# [441907 rows x 15 columns]

# %%
reverse_lookup = {}

for run_id in metadata.index.unique("run_id"):
    colors = metadata["color"][[run_id]]
    for color in colors.unique():
        mask = colors == color
        indices = colors[colors == color].index.tolist()
        reverse_lookup[(color, run_id)] = indices

assert reverse_lookup == col_run_to_exp

# %% [markdown]
# ## groupby solution
#
# https://stackoverflow.com/a/51329888/9318372

# %%
rev = metadata.groupby(["color", "run_id"]).groups
rev = {key: idx.tolist() for key, idx in rev.items()}
assert rev == col_run_to_exp

# %% [markdown]
# ## Custom splitting logic

# %%
from sklearn.model_selection import ShuffleSplit
from itertools import chain

splitter = ShuffleSplit(n_splits=5, random_state=0, test_size=0.25)
groups = metadata.groupby(["color", "run_id"])
rev_idx = groups.ngroup()
groups = metadata.groupby(["color", "run_id"])
group_idx = groups.ngroup()

splits = DataFrame(index=metadata.index)
for i, (train, test) in enumerate(splitter.split(groups)):
    splits[i] = group_idx.isin(train).map({False: "test", True: "train"})

splits.columns.name = "split"
splits.astype("string").astype("category")
# Out:
# split                     0      1      2      3      4
# run_id experiment_id
# 355    11722          train   test  train  train   test
#        11723          train  train  train   test   test
#        11724          train  train  train  train  train
#        11725           test  train   test  train   test
#        11726          train  train  train  train  train
# ...                     ...    ...    ...    ...    ...
# 510    16867           test   test  train   test  train
#        16868          train   test   test   test  train
#        16869          train  train   test   test  train
#        16870           test   test   test  train   test
#        16871          train  train   test  train  train
#
# [264 rows x 5 columns]

# %% [markdown]
# ## Loss function
#
# Divide 'Glucose' by 10, 'OD600' by 20, 'DOT' by 100, 'Base' by 200, then use RMSE.

# %%
targets = {"Glucose", "OD600", "DOT", "Base"}
assert targets <= set(timeseries.columns)

# %%
timeseries.min()
# Out:
# Flow_Air                  0.000000
# StirringSpeed             0.000000
# Temperature              32.689999
# Acetate                   0.000000
# Base                      0.000000
#                            ...
# Probe_Volume            200.000000
# pH                        0.000000
# Fluo_GFP                  0.000000
# InducerConcentration      0.000000
# Volume                    0.000000
# Length: 15, dtype: float32

# %%
timeseries.max()
# Out:
# Flow_Air                    10.000000
# StirringSpeed             2600.000000
# Temperature                 41.380001
# Acetate                      1.183919
# Base                      4070.000000
#                             ...
# Probe_Volume              5550.000000
# pH                           8.600000
# Fluo_GFP                586421.875000
# InducerConcentration         2.000000
# Volume                    2551.117188
# Length: 15, dtype: float32

# %%
timeseries.max() - timeseries.min()
# Out:
# Flow_Air                    10.000000
# StirringSpeed             2600.000000
# Temperature                  8.690002
# Acetate                      1.183919
# Base                      4070.000000
#                             ...
# Probe_Volume              5350.000000
# pH                           8.600000
# Fluo_GFP                586421.875000
# InducerConcentration         2.000000
# Volume                    2551.117188
# Length: 15, dtype: float32

# %%
from itertools import product

# %%
list(product(range(5), ("train", "test")))
# Out:
# [(0, 'train'),
#  (0, 'test'),
#  (1, 'train'),
#  (1, 'test'),
#  (2, 'train'),
#  (2, 'test'),
#  (3, 'train'),
#  (3, 'test'),
#  (4, 'train'),
#  (4, 'test')]

# %%
timeseries.dtypes
# Out:
# Flow_Air                Float32
# StirringSpeed           Float32
# Temperature             Float32
# Acetate                 Float32
# Base                    Float32
#                          ...
# Probe_Volume            Float32
# pH                      Float32
# Fluo_GFP                Float32
# InducerConcentration    Float32
# Volume                  Float32
# Length: 15, dtype: object

# %%
mask = splits[0] == "train"
idx = splits[0][mask].index
# Out:
# MultiIndex([(355, 11722),
#             (355, 11723),
#             (355, 11724),
#             (355, 11726),
#             (355, 11727),
#             (355, 11729),
#             (355, 11730),
#             (355, 11731),
#             (355, 11732),
#             (355, 11734),
#             ...
#             (510, 16858),
#             (510, 16860),
#             (510, 16861),
#             (510, 16863),
#             (510, 16864),
#             (510, 16865),
#             (510, 16866),
#             (510, 16868),
#             (510, 16869),
#             (510, 16871)],
#            names=['run_id', 'experiment_id'], length=189)

# %%
timeseries.reset_index(level=2).loc[idx].set_index(["measurement_time"], append=True)
# Out:
#                                           Flow_Air  StirringSpeed  \
# run_id experiment_id measurement_time
# 355    11722         2019-04-09 18:32:12      <NA>           <NA>
#                      2019-04-09 18:32:18      <NA>           <NA>
#                      2019-04-09 18:32:19      <NA>           <NA>
#                      2019-04-09 18:32:21  4.997213           <NA>
#                      2019-04-09 18:32:22      <NA>           <NA>
# ...                                            ...            ...
# 510    16871         2021-10-26 22:41:26      <NA>           <NA>
#                      2021-10-26 22:42:11      <NA>           <NA>
#                      2021-10-26 22:42:20      <NA>           <NA>
#                      2021-10-26 22:43:22      <NA>           <NA>
#                      2021-10-26 22:43:31      <NA>           <NA>
#
#                                           Temperature  Acetate  Base  \
# run_id experiment_id measurement_time
# 355    11722         2019-04-09 18:32:12    36.990002     <NA>  <NA>
#                      2019-04-09 18:32:18         <NA>     <NA>  <NA>
#                      2019-04-09 18:32:19         <NA>     <NA>  <NA>
#                      2019-04-09 18:32:21         <NA>     <NA>  <NA>
#                      2019-04-09 18:32:22        36.98     <NA>  <NA>
# ...                                               ...      ...   ...
# 510    16871         2021-10-26 22:41:26         <NA>     <NA>  <NA>
#                      2019-04-09 18:32:21                  <NA>    <NA>
#                      2019-04-09 18:32:22                  <NA>    <NA>
# ...                                                        ...     ...
# 510    16871         2021-10-26 22:41:26                  <NA>     0.0
#                      2021-10-26 22:42:11                  <NA>    <NA>
#                      2021-10-26 22:42:20                  <NA>    <NA>
#                      2021-10-26 22:43:22                  <NA>    <NA>
#                      2021-10-26 22:43:31                  <NA>    <NA>
#
# [326927 rows x 15 columns]

# %% [markdown]
# # Implementation

# %%
# %config InteractiveShell.ast_node_interactivity='last_expr_or_assign'  # always print last expr.
# %config InlineBackend.figure_format = 'svg'
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## Splits

# %%
from tsdm.tasks import KIWI_RUNS_TASK

TASK = KIWI_RUNS_TASK()

# %%
TASK.splits((4, "train"))[0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_347070/2436887867.py in <module>
# ----> 1 TASK.splits((4, "train"))[0]
#
# ~/Projects/KIWI/tsdm/tsdm/tasks/kiwi_runs.py in splits(self, key)
#     172         split, data_part = key
#     173
# --> 174         mask = self.split_idx[split] == data_part
#     175         idx = self.split_idx[split][mask].index
#     176         timeseries = self.timeseries.reset_index(level=2).loc[idx]
#
# ~/miniconda3/envs/kiwi/lib/python3.9/functools.py in __get__(self, instance, owner)
#     967                 val = cache.get(self.attrname, _NOT_FOUND)
#     968                 if val is _NOT_FOUND:
# --> 969                     val = self.func(instance)
#     970                     try:
#     971                         cache[self.attrname] = val
#
# ~/Projects/KIWI/tsdm/tsdm/tasks/kiwi_runs.py in split_idx(self)
#     147         """
#     148         splitter = ShuffleSplit(n_splits=5, random_state=0, test_size=0.25)
# --> 149         groups = self.metadata.groupby(["color", "run_id"])
#     150         group_idx = groups.ngroup()
#     151
#
# ~/miniconda3/envs/kiwi/lib/python3.9/site-packages/pandas/core/frame.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, dropna)
#    7629         # error: Argument "squeeze" to "DataFrameGroupBy" has incompatible type
#    7630         # "Union[bool, NoDefault]"; expected "bool"
# -> 7631         return DataFrameGroupBy(
#    7632             obj=self,
#    7633             keys=by,
#
# ~/miniconda3/envs/kiwi/lib/python3.9/site-packages/pandas/core/groupby/groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, squeeze, observed, mutated, dropna)
#     887             from pandas.core.groupby.grouper import get_grouper
#     888
# --> 889             grouper, exclusions, obj = get_grouper(
#     890                 obj,
#     891                 keys,
#
# ~/miniconda3/envs/kiwi/lib/python3.9/site-packages/pandas/core/groupby/grouper.py in get_grouper(obj, key, axis, level, sort, observed, mutated, validate, dropna)
#     860                 in_axis, level, gpr = False, gpr, None
#     861             else:
# --> 862                 raise KeyError(gpr)
#     863         elif isinstance(gpr, Grouper) and gpr.key is not None:
#     864             # Add key to exclusions
#
# KeyError: 'color'

# %% [markdown]
# ## Preprocessing

# %% [markdown]
# ### Encoding the metadata
#
# ```
# Feed_concentration_glc             Int16 → convert to float
# OD_Dilution                      Float32 → keep as-is
# bioreactor_id                     UInt32 → drop / One-Hot
# color                           category → drop / One-Hot
# container_number                  UInt32 → drop
# end_time                  datetime64[ns] → drop, but use for time-scaling
# organism_id                       UInt32 → One-Hot
# pH_correction_factor             Float32 → keep as-is
# profile_id                        UInt32 → drop
# profile_name                    category → drop
# run_name                        category → drop
# start_time                datetime64[ns] → drop, but use for time-scaling
# ```

# %%
ts = KIWI_RUNS.dataset
md = KIWI_RUNS.metadata

# %% [markdown]
# ### Consistency check: are the observation timestamps within start_time and end_time reported in metadata?

# %%
from tsdm.datasets import KIWI_RUNS
from tqdm.auto import tqdm

KIWI_RUNS.clean()

# %%
ts = KIWI_RUNS.dataset
ts

# %%
md = KIWI_RUNS.metadata
md
# ts = ts.reset_index(level="measurement_time")
# pandas.testing.assert_index_equal(md.index, ts.index.unique())

# %%
md.index.get_level_values([0, 1])

# %%
ts.drop(355)

# %%
merged = ts[[]].join(md[["start_time", "end_time"]])
time = merged.index.get_level_values("measurement_time")
cond = (merged["start_time"] <= time) & (time <= merged["end_time"])
ts[cond]

# %%
data[cond]

# %%
times = ts.reset_index()[["run_id", "experiment_id", "measurement_time"]]

# %%
times = ts.reset_index(level=2)[["measurement_time"]]

# %%
times

# %%
times = times.merge(start_stop, how="left", on=["run_id", "experiment_id"])

# %%
cond = (times["start_time"] <= times["measurement_time"]) & (
    times["measurement_time"] <= times["end_time"]
)

# %%
times[cond]

# %%
ts[cond.values]

# %%
for idx, group in ts.groupby(level=[0, 1]):
    valid_times = (md.loc[idx, "start_time"] <= ts.loc[idx].index) & (
        ts.loc[idx].index <= md.loc[idx, "end_time"]
    )
    ...

# %%
group.apply(lambda x: x[~valid_times])

# %%
group.app

# %%
for idx in tqdm(md.index):
    valid_times = (md.loc[idx, "start_time"] <= ts.loc[idx].index) & (
        ts.loc[idx].index <= md.loc[idx, "end_time"]
    )
    valid_index = ts.loc[idx].loc[valid_times].index
    # ts = ts.drop(valid_index)
    break

# %%
len(ts)

# %%
ts.loc[idx]

# %%
ts.loc[idx] = ts.loc[idx].drop(valid_index)

# %%
ts.loc[idx]

# %%
ts.drop()

# %%
for idx in tqdm(md.index):
    valid_times = (md.loc[idx, "start_time"] <= ts.loc[idx].index) & (
        ts.loc[idx].index <= md.loc[idx, "end_time"]
    )
    valid_index = ts.loc[idx].loc[valid_times].index
    # ts = ts.drop(valid_index)

# %%
len(ts)

# %%
valid_times

# %%
ts.loc[idx] = ts.loc[idx].loc[valid_times]

# %%
ts.loc[idx].loc[valid_times]

# %%
ts.loc[idx]["measurement_time"]

# %%
first_obs = ts["measurement_time"].groupby(["run_id", "experiment_id"]).min()

# %%
# ts = ts.reset_index(level=2)
runs = ts.index.get_level_values("run_id").unique()

times = DataFrame(
    index=md.index, columns=["ts_start", "ts_final", "md_start", "md_final"]
)

for idx in md.index:
    ts_slice = ts.loc[idx]
    md_slice = md.loc[idx]
    times.loc[idx, "ts_start"] = ts.loc[idx, "measurement_time"].min()
    times.loc[idx, "ts_final"] = ts.loc[idx, "measurement_time"].max()
    times.loc[idx, "md_start"] = md.loc[idx, "start_time"]
    times.loc[idx, "md_final"] = md.loc[idx, "end_time"]

times

# %%
discr = DataFrame()
discr["MD₀-TS₀"] = times["md_start"] - times["ts_start"]
discr["MDₜ-TSₜ"] = times["md_final"] - times["ts_final"]
discr = discr / np.timedelta64(1, "s")
discr = discr.groupby("run_id").mean()
with pd.option_context("display.float_format", "{:.0f}".format):
    display(discr)

# %% [markdown]
# ## What went wrong?

# %%
import matplotlib.pyplot as plt

times.loc[475, 16130]

# %%
exp = ts.loc[475, 16130]

# %%
pandas.isna(exp).mean()

# %%
T = exp["measurement_time"]
T = T - T.iloc[0]
DOT = exp["DOT"].astype(float).values
PH = exp["pH"].astype(float).values
TEMP = exp["Temperature"].astype(float).values

# %%
exp.set_index("measurement_time")

# %%
slc.iloc[-1]

# %%
slc = exp.set_index("measurement_time").loc[:"2021-06-01"]
pandas.isna(slc).mean()

# %%
fig, ax = plt.subplots(figsize=(10, 4))
ax.plot(T, DOT, T, PH, T, TEMP)
ax.legend(["DOT", "pH", "Temp"])

# %%
DataFrame.from_dict(start_times, orient=)

# %%
metadata["start_time"]

# %%
md = metadata.drop(355)
assert not pandas.isna(md).any(axis=None), "DataFrame contains NANs!!"

# %%
drop_vals = [
    "bioreactor_id",
    "color",
    "container_number",
    "end_time",
    "start_time",
    "profile_id",
    "profile_name",
    "run_name",
    "organism_id",
]

# %%
md = md.drop(columns=drop_vals).astype("Float32")

# %%
md["Feed_concentration_glc"] = md["Feed_concentration_glc"].astype("Float32")

# %%
md["organism_id"] = md["organism_id"].astype("category")

# %%
pandas.get_dummies(md, columns=["organism_id"])

# %%
from sklearn.preprocessing import StandardScaler

# %%
preprocessor = StandardScaler()
ts, md = TASK.splits((4, "train"))

# %%
preprocessor.fit(ts)
preprocessor.transform(ts, copy=False)
ts

# %% [markdown]
# ## Encoding in torch

# %%
import torch
from tsdm.encoders.functional import time2float

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
dtype = torch.float32
ts = ts.reset_index(level=2)  # make measurements regular col

# %%
time2float(ts["measurement_time"].values)

# %%
T = torch.tensor(time2float(ts["measurement_time"].values), device=device, dtype=dtype)
X = torch.tensor(
    ts.drop(columns=["measurement_time"]).values, device=device, dtype=dtype
)

# %% [markdown]
# ## Creating DataSetCollection Object

# %%
from tsdm.datasets import DataSetCollection
from torch.utils.data import TensorDataset

# %%
shared_index = ts.index.unique().values
masks = {idx: (ts.index == idx) for idx in shared_index}
datasets = {idx: TensorDataset(T[masks[idx]], X[masks[idx]]) for idx in shared_index}

# %%
from pandas import Series

# %%
s = Series(datasets)

# %%
dataset = DataSetCollection(datasets)

# %%
some_index = ts.index.values[42]
dataset[some_index]

# %%
dataset[some_index][:10]

# %% [markdown]
# ## Creating CollectionSampler Object

# %%
from tsdm.util.samplers import CollectionSampler, SequenceSampler
from torch.utils.data import TensorDataset
from functools import partial

subsampler = partial(SequenceSampler, seq_len=100, shuffle=True)
sampler = CollectionSampler(dataset, subsampler=subsampler)

# %%
sample = next(iter(sampler))
element = dataset[sample]

# %%
from tqdm.auto import tqdm

for b in tqdm(sampler):
    ...

# %% [markdown]
# ## DataLoader Object

# %%
from torch.utils.data import DataLoader

# %%
dloader = DataLoader(dataset, sampler=sampler, batch_size=32)

# %%
next(iter(dloader))

# %%
for batch in tqdm(dloader):
    ...

# %% [markdown]
# ## Testing implemented variant

# %%
from tsdm.tasks import KIWI_RUNS_TASK

task = KIWI_RUNS_TASK()

# %%
task.dataloaders

# %%
dloader = task.batchloader[0]

# %%
T, X = next(iter(dloader))

# %%
T.shape, X.shape

# %%
for batch in tqdm(dloader):
    ...

# %%
for batch in tqdm(task.dataloaders[(0, "train")]):
    ...
