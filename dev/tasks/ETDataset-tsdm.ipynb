# %%
# %config InteractiveShell.ast_node_interactivity='last_expr_or_assign'  # always print last expr.
# %config InlineBackend.figure_format = 'svg'
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

import logging
logging.basicConfig(level=logging.INFO)

# %% [markdown]
# # Implemented Task

# %%
from tsdm.tasks import ETDatasetTask_Informer
# Out:
# INFO:numexpr.utils:Note: NumExpr detected 24 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# INFO:numexpr.utils:NumExpr defaulting to 8 threads.
# INFO:tsdm.config._config:Available Models: {'N-BEATS', 'GRU-ODE-Bayes', 'TFT', 'IP-Net', 'BRITS', 'mTAN', 'NCDE', 'Latent-ODE', 'TPA', 'Informer', 'ODE-RNN', 'M-RNN', 'SET-TS', 'NODE'}
# INFO:tsdm.config._config:Available Datasets: {'Electricity', 'M3', 'USHCN', 'Traffic', 'Physionet 2019', 'Physionet 2012', 'Household Consumption', 'tourism2', 'tourism1', 'Air Quality', 'M4', 'UWAVE', 'Human Activity', 'M5', 'Character Trajectories', 'MuJoCo', 'Air Quality Multi-Site'}
# INFO:tsdm.config._config:Initializing folder structure
# INFO:tsdm.config._config:creating folder /home/rscholz/.tsdm/datasets
# INFO:tsdm.config._config:creating folder /home/rscholz/.tsdm/models
# INFO:tsdm.config._config:creating folder /home/rscholz/.tsdm/logs
# INFO:tsdm.config._config:creating folder /home/rscholz/.tsdm/rawdata
# INFO:tsdm.config._config:Created folder structure in /home/rscholz/.tsdm
# WARNING:tsdm.datasets.ushcn:Using Modin with Ray Backend

# %%
task = ETDatasetTask_Informer()
# Out:
# INFO:tsdm.datasets.base._base:ETT: START loading dataset!
# INFO:tsdm.datasets.base._base:ETT/ETTh1: START loading dataset!
# INFO:tsdm.datasets.base._base:ETT/ETTh1: DONE loading dataset!
# INFO:tsdm.datasets.base._base:ETT/ETTh2: START loading dataset!
# INFO:tsdm.datasets.base._base:ETT/ETTh2: DONE loading dataset!
# INFO:tsdm.datasets.base._base:ETT/ETTm1: START loading dataset!
# INFO:tsdm.datasets.base._base:ETT/ETTm1: DONE loading dataset!
# INFO:tsdm.datasets.base._base:ETT/ETTm2: START loading dataset!
# INFO:tsdm.datasets.base._base:ETT/ETTm2: DONE loading dataset!
# INFO:tsdm.datasets.base._base:ETT: DONE loading dataset!
# ETDatasetTask_Informer(dataset=ETTh1, test_metric=MSELoss)

# %%
task.batchloaders
# Out:
# LazyDict(
#   train: <LazyFunction: get_dataloader>
#   valid: <LazyFunction: get_dataloader>
#   joint: <LazyFunction: get_dataloader>
#   trial: <LazyFunction: get_dataloader>
#   whole: <LazyFunction: get_dataloader>
#   test : <LazyFunction: get_dataloader>
# )

# %%
dataloader = task.batchloaders["train"]
batch = next(iter(dataloader))
# Out:
# [tensor([[0.1725, 0.1726, 0.1727,  ..., 0.1859, 0.1860, 0.1861],
#          [0.2345, 0.2346, 0.2347,  ..., 0.2479, 0.2480, 0.2481],
#          [0.3937, 0.3938, 0.3939,  ..., 0.4070, 0.4071, 0.4072],
#          ...,
#          [0.0433, 0.0434, 0.0435,  ..., 0.0566, 0.0567, 0.0569],
#          [0.8458, 0.8459, 0.8460,  ..., 0.8591, 0.8592, 0.8593],
#          [0.3747, 0.3748, 0.3749,  ..., 0.3881, 0.3882, 0.3883]],
#         device='cuda:0'),
#  tensor([[[ 4.9384e-01,  1.4759e+00,  5.2658e-01,  ..., -4.3412e-01,
#             3.1648e-01,  1.0714e+00],
#           [ 7.2390e-01,  1.9590e+00,  7.9615e-01,  ..., -4.9392e-01,
#             4.5820e-01,  1.0560e+00],
#           [ 5.1686e-01,  1.7657e+00,  5.7157e-01,  ..., -5.2333e-01,
#             3.6320e-01,  1.0020e+00],
#           ...,
#           [-3.9239e-01,  1.8800e-01, -2.6968e-01,  ..., -5.8312e-01,
#            -1.6797e-02,  2.5398e-01],
#           [-5.0734e-01,  3.1683e-01, -3.1449e-01,  ..., -9.7131e-01,
#            -6.3518e-02,  3.8029e-02],
#           [-5.5339e-01,  2.2021e-01, -1.9253e-01,  ..., -1.3889e+00,
#            -3.4852e-01,  3.8029e-02]],
#
#          [[-2.3123e-01,  9.2880e-01, -7.0569e-02,  ..., -6.4292e-01,
#             5.9992e-01,  1.1331e+00],
#           [-1.0460e-01,  9.6101e-01, -5.7740e-02,  ..., -3.4394e-01,
#             6.9492e-01,  1.0869e+00],
#           [-1.0460e-01,  8.3217e-01,  6.5815e-03,  ..., -6.7233e-01,
#             5.9992e-01,  1.0560e+00],
#           ...,
#           [-4.6146e-01,  1.2358e-01, -3.9796e-01,  ..., -2.8414e-01,
#            -6.3518e-02, -7.7163e-01],
#           [-5.0734e-01, -3.7463e-02, -4.3012e-01,  ..., -9.7131e-01,
#             7.8202e-02, -5.5567e-01],
#           [-5.6490e-01,  3.1683e-01, -3.1449e-01,  ..., -1.0007e+00,
#            -2.0524e-01, -2.7033e-01]],
#
#          [[-2.0821e-01,  2.8462e-01, -7.0569e-02,  ..., -7.3212e-01,
#             7.8202e-02, -6.2164e-02],
#           [ 7.9415e-02,  2.5242e-01,  5.7895e-02,  ...,  1.9325e-01,
#             2.2148e-01, -2.0873e-01],
#           [-4.7042e-02,  1.5579e-01, -3.2084e-02,  ..., -1.5550e-02,
#            -1.5852e-01, -1.0075e-01],
#           ...,
#           [ 7.9415e-02,  7.9996e-01,  9.6379e-02,  ..., -4.0373e-01,
#             2.6820e-01, -6.8678e-01],
#           [ 4.5051e-02,  7.6776e-01,  1.4137e-01,  ..., -6.1253e-01,
#             1.7320e-01, -4.8629e-01],
#           [-9.9559e-04,  7.6776e-01,  1.2204e-01,  ..., -5.8312e-01,
#             7.8202e-02, -6.6365e-01]],
#
#          ...,
#
#          [[-2.0821e-01, -3.9128e-01, -1.4754e-01,  ..., -3.7433e-01,
#             3.6320e-01,  1.8040e+00],
#           [-1.2507e-02, -3.9128e-01, -1.2751e-02,  ...,  7.3654e-02,
#             3.1648e-01,  1.6421e+00],
#           [-8.1577e-02, -3.5907e-01, -8.3397e-02,  ..., -1.3514e-01,
#             3.1648e-01,  1.6266e+00],
#           ...,
#           [ 5.6563e-02,  2.6954e-02,  1.9268e-01,  ..., -6.4292e-01,
#             2.6820e-01,  2.1433e+00],
#           [ 2.5209e-01,  9.1372e-02,  2.1201e-01,  ...,  5.5104e-01,
#             9.7992e-01,  2.1587e+00],
#           [ 2.6360e-01,  4.1346e-01,  1.6052e-01,  ...,  6.4123e-01,
#             9.3320e-01,  1.9505e+00]],
#
#          [[-1.7618e+00,  4.7788e-01, -1.7784e+00,  ..., -2.2435e-01,
#             7.4320e-01,  2.0772e-01],
#           [-1.0828e+00,  9.1372e-02, -1.0464e+00,  ..., -2.2435e-01,
#             2.2148e-01,  3.0802e-01],
#           [-4.4995e-01, -2.3024e-01, -4.4295e-01,  ..., -1.3514e-01,
#             7.8202e-02,  3.3883e-01],
#           ...,
#           [-4.3052e+00,  6.3892e-01, -4.4557e+00,  ..., -4.6353e-01,
#             5.5320e-01,  3.6196e-01],
#           [-3.8219e+00,  5.7450e-01, -4.0126e+00,  ..., -4.3412e-01,
#             5.5320e-01,  5.1619e-01],
#           [-3.2925e+00,  3.4904e-01, -3.3770e+00,  ..., -5.8312e-01,
#             4.5820e-01,  5.9325e-01]],
#
#          [[-8.1577e-02, -4.5570e-01, -1.9256e-02,  ..., -2.2435e-01,
#            -2.3871e+00,  9.2071e-02],
#           [-1.2762e-01, -4.5570e-01, -5.1236e-02,  ..., -3.1453e-01,
#            -2.8621e+00,  1.4600e-01],
#           [-2.5425e-01, -5.2011e-01, -1.6037e-01,  ..., -6.7233e-01,
#            -2.9104e+00,  3.8029e-02],
#           ...,
#           [ 2.9814e-01,  1.2831e+00,  2.6333e-01,  ..., -4.6353e-01,
#             5.5320e-01,  1.4899e-02],
#           [ 2.5209e-01,  8.3217e-01,  3.9179e-01,  ...,  2.8245e-01,
#             3.1648e-01, -4.4807e-04],
#           [ 4.5930e-01,  3.1683e-01,  3.7896e-01,  ...,  7.9023e-01,
#             1.7320e-01, -8.5294e-02]]], device='cuda:0')]
