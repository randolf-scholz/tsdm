# %% [markdown]
# # Is it possible to add a different collate_fn after initialization?

# %%
# %config InteractiveShell.ast_node_interactivity='last_expr_or_assign'  # always print last expr.
# %config InlineBackend.figure_format = 'svg'
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

import logging
logging.basicConfig(level=logging.INFO)

# %%
import torch
from torch import Tensor
from torch.utils.data import DataLoader
from torch.utils.data.dataloader import default_collate
# Out:
# INFO:numexpr.utils:Note: NumExpr detected 24 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# INFO:numexpr.utils:NumExpr defaulting to 8 threads.

# %%
data = torch.randn(100, 10)
dloader = DataLoader(data, num_workers=4)

# %%
next(iter(dloader))
# Out:
# tensor([[ 0.1504, -0.5632, -1.2691, -1.1175, -1.5953, -1.8088,  0.7923, -0.3907,
#          -0.2508, -0.3333]])

# %%
def my_collate(x: list[Tensor]) -> Tensor:
    x = default_collate(x)
    x = torch.nn.functional.relu(x)
    return x

# %%
dloader.collate_fn = my_collate

# %%
next(iter(dloader))
# Out:
# tensor([[0.1504, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.7923, 0.0000, 0.0000,
#          0.0000]])

# %%
from typing import NamedTuple

# %%
class Batch(NamedTuple):
    index: Tensor
    timeseries: Tensor
    metadata: Tensor
    targets: Tensor
    # encoded_targets: Tensor

# %%
from collections.abc import Mapping
isinstance(Batch(1,2,3,4), Mapping)
# Out:
# False

# %%
obj = Batch(1,2,3,4)
# Out:
# Batch(index=1, timeseries=2, metadata=3, targets=4)

# %%
Batch(**obj._asdict())
# Out:
# Batch(index=1, timeseries=2, metadata=3, targets=4)

# %%
isinstance(obj, NamedTuple)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [16], in <module>
# ----> 1 isinstance(obj, NamedTuple)
#
# TypeError: isinstance() arg 2 must be a type or tuple of types

# %%
isinstance(None, tuple)
# Out:
# False

# %%
from collections.abc import
# Out:
#   Input In [20]
#     from collections.abc import
#                                 ^
# SyntaxError: invalid syntax

# %%
NamedTuple()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [19], in <module>
# ----> 1 NamedTuple()
#
# TypeError: NamedTuple() missing 1 required positional argument: 'typename'

# %%
obj._fields
# Out:
# ('index', 'timeseries', 'metadata', 'targets')

# %%
from numpy.typing import NDArray

# %%
tuple(*(x for x in obj))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [59], in <module>
# ----> 1 tuple(*(x for x in obj))
#
# TypeError: tuple expected at most 1 argument, got 4

# %%
issubclass(type(obj), tuple)
# Out:
# True

# %%
namedtuple
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [28], in <module>
# ----> 1 isinstance([], NDArray)
#
# TypeError: isinstance() argument 2 cannot be a parameterized generic

# %%
tuple(*obj)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [42], in <module>
# ----> 1 tuple(*obj)
#
# TypeError: tuple expected at most 1 argument, got 4

# %%
Batch(*obj)
# Out:
# Batch(index=1, timeseries=2, metadata=3, targets=4)

# %%
dir(obj)
# Out:
# ['__add__',
#  '__annotations__',
#  '__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__module__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__orig_bases__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__slots__',
#  '__str__',
#  '__subclasshook__',
#  '_asdict',
#  '_field_defaults',
#  '_fields',
#  '_make',
#  '_replace',
#  'count',
#  'index',
#  'metadata',
#  'targets',
#  'timeseries']
