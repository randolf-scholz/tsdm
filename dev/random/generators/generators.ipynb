# %%
# %config InteractiveShell.ast_node_interactivity='last_expr_or_assign'  # always print last expr.

# %%
# THIS CELL WAS AUTO-GENERATED BY PYFLYBY


# END AUTO-GENERATED BLOCK

# %%
import tsdm
from tsdm.random.generators import BouncingBall, DampedPendulum, LoktaVolterra

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# # Bouncing Ball

# %%
t = np.linspace(-10, 20, 1000)
y0 = np.random.uniform(-0.5, 0.7, size=(5, 2))
x = BouncingBall().solve_ivp(t, y0=y0)
plt.plot(t, x[0], t, x[1], t, x[3])
