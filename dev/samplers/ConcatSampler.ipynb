# %% [markdown]
# # ConcatSampler
#
# Sample uniformly from either of the given samplers.

# %%
# %config InteractiveShell.ast_node_interactivity='last_expr_or_assign'  # always print last expr.
# %config InlineBackend.figure_format = 'svg'
# %load_ext autoreload
# %autoreload 2
# %matplotlibinline
# Out:
# UsageError: Line magic function `%matplotlibinline` not found.

# %%
from tsdm.random.samplers import *

# %%
class ConcatSampler(BaseSampler):
    """Given multiple samplers, create a new one"""

    
    def __init__(self, *samplers) -> None:
        ...

        
    def __len__(self) -> int:
        r"""Return the length of the sampler."""

# %%
ConcatSampler()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [4], in <cell line: 1>()
# ----> 1 ConcatSampler()
#
# TypeError: Can't instantiate abstract class ConcatSampler with abstract methods __iter__, __len__
