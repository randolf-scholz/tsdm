# %%
# %config InteractiveShell.ast_node_interactivity='last_expr_or_assign'  # always print last expr.
# %config InlineBackend.figure_format = 'svg'
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
import logging
import tsdm
from tsdm.util.decorators import trace, timefun

logging.basicConfig(level=logging.INFO)

# %%
from functools import wraps

def compose(f, g):
    
    @f
    def wrapper(*args, **kwargs):
        return g(*args, **kwargs)
    
    return wrapper

# %%
def myfun(x):
    return x

# %%
g = compose( compose(trace, timefun), myfun)
h = compose( trace, compose(timefun, myfun))
# Out:
# INFO:trace:Entering wrapper:args=(<function compose.<locals>.wrapper at 0x7f03fb6899d0>,)
# kwargs={}
# INFO:trace:Exiting wrapper:
# result=<bound method compose.<locals>.wrapper of <function compose.<locals>.wrapper at 0x7f03fb6899d0>>
# INFO:tsdm.util.decorators.decorators:>>> Generating bracket version of <function decorator at 0x7f0404043040> <<<
# <function __main__.compose.<locals>.wrapper(*args, **kwargs)>

# %%
dir(myfun)
# Out:
# ['__annotations__',
#  '__call__',
#  '__class__',
#  '__closure__',
#  '__code__',
#  '__defaults__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__get__',
#  '__getattribute__',
#  '__globals__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__kwdefaults__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__name__',
#  '__ne__',
#  '__new__',
#  '__qualname__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__']

# %%
g(2)
# Out:
# WARNING:timefun:wrapper executed in 0.0000 s
# (2, 5.58e-06)

# %%
h(2)
# Out:
# INFO:trace:Entering wrapper:args=(2,)
# kwargs={}
# WARNING:timefun:wrapper executed in 0.0000 s
# INFO:trace:Exiting wrapper:
# result=(2, 3.371e-06)
# (2, 3.371e-06)

# %%
h(2)
# Out:
# INFO:tsdm.util.decorators.decorators:>>> Generating bracket version of <function decorator at 0x7fc9a14ea160> <<<
# <tsdm.util.decorators.decorators.trace.<locals>.Trace at 0x7fcb3625bf40>

# %%
@trace
@timefun
def f(x):
    return x

f(2)
# Out:
# INFO:tsdm.util.decorators.decorators:>>> Generating bracket version of <function decorator at 0x7fc0ed212160> <<<
# INFO:trace:Entering f:args=(2,)
# kwargs={}
# WARNING:timefun:f executed in 0.0000 s
# INFO:trace:Exiting f:
# result=(2, 2.86e-06)
# (2, 2.86e-06)

# %%
# Out:
# INFO:trace:Entering f:args=(2,)
# kwargs={}
# INFO:trace:Exiting f:
# result=2
# WARNING:timefun:f executed in 0.0007 s
# (2, 0.000672874)

# %%
h(2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_39844/2279919371.py in <module>
# ----> 1 h(2)
#
# TypeError: 'tuple' object is not callable

# %%
timefun(trace)
# Out:
# INFO:tsdm.util.decorators.decorators:>>> Generating bracket version of <function decorator at 0x7fc0ed212160> <<<
# <function tsdm.util.decorators.decorators.trace(func: 'Callable') -> 'Callable'>
