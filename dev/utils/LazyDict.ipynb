# %% [markdown]
# # Title

# %%
# %config InteractiveShell.ast_node_interactivity='last_expr_or_assign'  # always print last expr.
# %config InlineBackend.figure_format = 'svg'
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
import inspect

# %%
inspect.signature(dict.__init__)
# Out:
# <Signature (self, /, *args, **kwargs)>

# %%
tuplesA = [(1,2,3), (2,4)]
tuplesB = [("a", 7), ("b", 67)]
# Out:
# [('a', 7), ('b', 67)]

# %%
from tsdm.util import LazyDict

# %%
def f(*, key=0):
    return 2+key
from functools import partial

# %%
tuples = [("f1", (lambda x: x, (2,), {})), ("f2", (lambda: "jo", (), {})), ("f3", lambda: "Hello"),
         ("f4", partial(f, key=-99))]
# Out:
# [('f1', (<function __main__.<lambda>(x)>, (2,), {})),
#  ('f2', (<function __main__.<lambda>()>, (), {})),
#  ('f3', <function __main__.<lambda>()>),
#  ('f4', functools.partial(<function f at 0x7f3377437ee0>, key=-99))]

# %%
ld = LazyDict(tuples)
# Out:
# LazyDict(
#   f1: Uninitialized(func=<function <lambda> at 0x7f3377437790>, args=(2,), kwargs={})
#   f2: Uninitialized(func=<function <lambda> at 0x7f3377437a60>, args=(), kwargs={})
#   f3: Uninitialized(func=<function <lambda> at 0x7f33774a6dc0>, args=(), kwargs={})
#   f4: Uninitialized(func=functools.partial(<function f at 0x7f3377437ee0>, key=-99), args=(), kwargs={})
# )

# %%
g = ld._dict.get("f4").func
# Out:
# functools.partial(<function f at 0x7f3377437ee0>, key=-99)

# %%
inspect.signature(g)
# Out:
# <Signature (*, key=-99)>

# %%
ld["f4"]
# Out:
# Called __getitem__ for f4
# -97

# %%
dict(item for item in tuples)
# Out:
# {'f1': (<function __main__.<lambda>(x)>, (2,), {}),
#  'f2': (<function __main__.<lambda>()>, (), {}),
#  'f3': <function __main__.<lambda>()>}

# %%
ld
# Out:
# LazyDict(
#   f1: Uninitialized(func=<function <lambda> at 0x7f3377431040>, args=(2,), kwargs={})
#   f2: Uninitialized(func=<function <lambda> at 0x7f3377431a60>, args=(), kwargs={})
#   f3: Hello
# )

# %%
ld["f3"]
# Out:
# Called __getitem__ for f3
# 'Hello'

# %%
a, b, c = ld._dict.get("f3")

# %%
import numpy as np
import matplotlib.pyplot as plt

np.set_printoptions(precision=4, floatmode='fixed', suppress=True)
rng = np.random.default_rng()

# %%
f(*(), **{})
# Out:
# 2

# %%
tup = (1,2,3)
# Out:
# [autoreload of tsdm.util.lazydict failed: Traceback (most recent call last):
#   File "/home/rscholz/miniconda3/envs/kiwi/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/rscholz/miniconda3/envs/kiwi/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 394, in superreload
#     module = reload(module)
#   File "/home/rscholz/miniconda3/envs/kiwi/lib/python3.9/imp.py", line 314, in reload
#     return importlib.reload(module)
#   File "/home/rscholz/miniconda3/envs/kiwi/lib/python3.9/importlib/__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 613, in _exec
#   File "<frozen importlib._bootstrap_external>", line 846, in exec_module
#   File "<frozen importlib._bootstrap_external>", line 983, in get_code
#   File "<frozen importlib._bootstrap_external>", line 913, in source_to_code
#   File "<frozen importlib._bootstrap>", line 228, in _call_with_frames_removed
#   File "/home/rscholz/Projects/KIWI/tsdm/tsdm/util/lazydict.py", line 37
#     if isinstance(value, tuple) and len(value) == 3:
# IndentationError: expected an indented block
# ]
# (1, 2, 3)

# %%
g = lambda: 2
# Out:
# <function __main__.<lambda>()>

# %%
g.__name__
# Out:
# '<lambda>'
