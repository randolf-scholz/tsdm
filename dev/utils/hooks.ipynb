# %% [markdown]
# # Title

# %%
# %config InteractiveShell.ast_node_interactivity='last_expr_or_assign'  # always print last expr.
# %config InlineBackend.figure_format = 'svg'
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

import logging
logging.basicConfig(level=logging.INFO)

# %%
import numpy as np
import matplotlib.pyplot as plt

np.set_printoptions(precision=4, floatmode='fixed', suppress=True)
rng = np.random.default_rng()

# %%
from abc import ABC, abstractmethod
from tsdm.util.decorators  import decorator


@decorator
def create_hooks(func, pre_hook, post_hook, /):
    def wrapper(*args, **kwargs):
        pre_hook(*args, **kwargs)
        result = func(*args, **kwargs)
        post_hook(*args, **kwargs)
        return result
    return wrapper



class A(ABC):
    
    def __init__(self):
        self.func = create_hooks(self.func, self.pre_func, None)
    
    def _pre_func(self):
        print("JAMONA !")
    
    def func(self):
        ...

class B(A):
    
    def func(self):
        return 42

# %%
B().func()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [33], in <module>
# ----> 1 B().func()
#
# Input In [32], in A.__init__(self)
#      17 def __init__(self):
# ---> 18     self.func = create_hooks(self.func, self.pre_func, None)
#
# AttributeError: 'B' object has no attribute 'pre_func'
