# %% [markdown]
# # Title

# %%
# %config InteractiveShell.ast_node_interactivity='last_expr_or_assign'  # always print last expr.
# %config InlineBackend.figure_format = 'svg'
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
import numpy as np
import matplotlib.pyplot as plt

np.set_printoptions(precision=4, floatmode='fixed', suppress=True)
rng = np.random.default_rng()

# %%
from functools import wraps
from collections.abc import Iterable, Callable
from typing import TypeVar

# %%
def apply_on_iter(cls: Iterable, func: Callable) -> Iterable:

    iter_method = getattr(cls, "__iter__")

    @wraps(iter_method)
    def wrapper():
        for x in iter_method():
            yield func(x)

    setattr(cls, "__iter__", wrapper)
    
    return cls

# %%
def f(x): return x+7

# %%
tup = (1,2,3,4)

tup = apply_on_iter(tup, f)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_45980/4058428924.py in <module>
#       1 tup = (1,2,3,4)
#       2
# ----> 3 tup = apply_on_iter(tup, f)
#
# /tmp/ipykernel_45980/219218063.py in apply_on_iter(cls, func)
#       8             yield func(x)
#       9
# ---> 10     setattr(cls, "__iter__", wrapper)
#      11
#      12     return cls
#
# AttributeError: 'tuple' object attribute '__iter__' is read-only

# %%
from torch.utils.data import default_collate
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# /tmp/ipykernel_45980/2483868563.py in <module>
# ----> 1 from torch.utils.data import default_collate
#
# ImportError: cannot import name 'default_collate' from 'torch.utils.data' (/home/rscholz/miniconda3/envs/kiwi/lib/python3.9/site-packages/torch/utils/data/__init__.py)

# %%
dir(data)
# Out:
# ['BatchSampler',
#  'ChainDataset',
#  'ConcatDataset',
#  'DFIterDataPipe',
#  'DataChunk',
#  'DataLoader',
#  'DataLoader2',
#  'Dataset',
#  'DistributedSampler',
#  'IterDataPipe',
#  'IterableDataset',
#  'MapDataPipe',
#  'RandomSampler',
#  'Sampler',
#  'SequentialSampler',
#  'Subset',
#  'SubsetRandomSampler',
#  'TensorDataset',
#  'WeightedRandomSampler',
#  '_DatasetKind',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '_decorator',
#  '_typing',
#  '_utils',
#  'argument_validation',
#  'backward_compatibility',
#  'communication',
#  'dataloader',
#  'dataloader_experimental',
#  'datapipes',
#  'dataset',
#  'distributed',
#  'functional_datapipe',
#  'get_worker_info',
#  'graph',
#  'guaranteed_datapipes_determinism',
#  'non_deterministic',
#  'random_split',
#  'runtime_validation',
#  'runtime_validation_disabled',
#  'sampler',
#  'sharding']

# %%
def dec(instance):
    
    cls = type(instance)
    
    @functools.wraps(cls, updated=())
    class Wrapped(cls):
        
        def __new__(cls, *args, **kwargs):
            return instance
        
        
        def __iter__(self):
            
            
            
            
            
        
        decorated = 1
    return D

# %%
def
