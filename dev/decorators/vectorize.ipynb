# %% [markdown]
# # Title

# %%
# %config InteractiveShell.ast_node_interactivity='last_expr_or_assign'  # always print last expr.
# %config InlineBackend.figure_format = 'svg'
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
import numpy as np
import matplotlib.pyplot as plt

np.set_printoptions(precision=4, floatmode='fixed', suppress=True)
rng = np.random.default_rng()
# Out:
# Generator(PCG64) at 0x7F9747A88740

# %%
from tsdm.util.decorators import decorator

# %%
from functools import wraps
from typing import Callable

# %%
@decorator
def vectorize(func, kind: type, /):
    """Vectorize a function with a single input. The signature will change accordingly
    func: Callable[[ObjectType], ReturnType]
    wrappend: Callable[[*ObjectType], *ReturnType]
    """
    
    @wraps(func)
    def wrapper(arg, *args):
        if not args:
            return func(arg)
        return kind(func(x) for x in (arg, *args))
    return wrapper

# %%
from tsdm.util.decorators import vectorize
# Out:
# Using Modin with Ray Backend

# %%
@vectorize(list)
def f(x):
    return x + 1

assert f(1) == 2
assert f(1,2) == [2,3]

# %%
f(1,2,3)
# Out:
# [2, 3, 4]

# %%
import inspect

dir(inspect.signature(f))
# Out:
# ['__class__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setstate__',
#  '__sizeof__',
#  '__slots__',
#  '__str__',
#  '__subclasshook__',
#  '_bind',
#  '_bound_arguments_cls',
#  '_hash_basis',
#  '_parameter_cls',
#  '_parameters',
#  '_return_annotation',
#  'bind',
#  'bind_partial',
#  'empty',
#  'from_builtin',
#  'from_callable',
#  'from_function',
#  'parameters',
#  'replace',
#  'return_annotation']

# %%
params = list(inspect.signature(f).parameters.values())
# Out:
# [autoreload of tsdm.util.decorators._decorators failed: Traceback (most recent call last):
#   File "/home/rscholz/miniconda3/envs/kiwi/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/rscholz/miniconda3/envs/kiwi/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 394, in superreload
#     module = reload(module)
#   File "/home/rscholz/miniconda3/envs/kiwi/lib/python3.9/imp.py", line 314, in reload
#     return importlib.reload(module)
#   File "/home/rscholz/miniconda3/envs/kiwi/lib/python3.9/importlib/__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 613, in _exec
#   File "<frozen importlib._bootstrap_external>", line 846, in exec_module
#   File "<frozen importlib._bootstrap_external>", line 983, in get_code
#   File "<frozen importlib._bootstrap_external>", line 913, in source_to_code
#   File "<frozen importlib._bootstrap>", line 228, in _call_with_frames_removed
#   File "/home/rscholz/Projects/KIWI/tsdm/tsdm/util/decorators/_decorators.py", line 333
#     def get_param_type_counts:
#                              ^
# SyntaxError: invalid syntax
# ]
# [<Parameter "x">]

# %%
params[0].kind is inspect.Parameter.POSITIONAL_OR_KEYWORD
# Out:
# True

# %%
params[0][1].kind
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_211070/2063998194.py in <module>
# ----> 1 params[0][1].kind
#
# TypeError: 'odict_items' object is not subscriptable
