# %%
# %config InteractiveShell.ast_node_interactivity='last_expr_or_assign'  # always print last expr.
# %config InlineBackend.figure_format = 'svg'
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

import logging
logging.basicConfig(level=logging.INFO)

# %%
from tsdm.datasets import InSilicoData
ds = InSilicoData()
# Out:
# INFO:numexpr.utils:Note: NumExpr detected 24 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# INFO:numexpr.utils:NumExpr defaulting to 8 threads.
# INFO:tsdm.config._config:Available Models: {'Latent-ODE', 'NODE', 'BRITS', 'ODE-RNN', 'IP-Net', 'TPA', 'GRU-ODE-Bayes', 'TFT', 'NCDE', 'SET-TS', 'N-BEATS', 'mTAN', 'M-RNN', 'Informer'}
# INFO:tsdm.config._config:Available Datasets: {'Physionet 2012', 'Human Activity', 'MuJoCo', 'M5', 'Household Consumption', 'Air Quality', 'tourism2', 'M3', 'Air Quality Multi-Site', 'UWAVE', 'Traffic', 'M4', 'USHCN', 'Physionet 2019', 'Electricity', 'Character Trajectories', 'tourism1'}
# INFO:tsdm.config._config:Initializing folder structure
# INFO:tsdm.config._config:creating folder /home/rscholz/.tsdm/datasets
# INFO:tsdm.config._config:creating folder /home/rscholz/.tsdm/models
# INFO:tsdm.config._config:creating folder /home/rscholz/.tsdm/logs
# INFO:tsdm.config._config:creating folder /home/rscholz/.tsdm/rawdata
# INFO:tsdm.config._config:Created folder structure in /home/rscholz/.tsdm
# INFO:tsdm.datasets.base._base:InSilicoData: START loading dataset!
# INFO:tsdm.datasets.base._base:InSilicoData: Rawdata files already exist!
# INFO:tsdm.datasets.base._base:InSilicoData: Dataset files already exist!
# INFO:tsdm.datasets.base._base:InSilicoData: DONE loading dataset!

# %%
ds
# Out:
# INFO:tsdm.datasets.base._base:InSilicoData: START loading dataset!
# INFO:tsdm.datasets.base._base:InSilicoData: Rawdata files already exist!
# INFO:tsdm.datasets.base._base:InSilicoData: Dataset files already exist!
# INFO:tsdm.datasets.base._base:InSilicoData: DONE loading dataset!
# InSilicoData
#                             Biomass  Substrate  Acetate      DOTm  Product  \
# run_id time
# 16130  2021-06-28 09:41:57      NaN        NaN      NaN       NaN      NaN
#        2021-06-28 09:53:38      NaN        NaN      NaN  0.983902      NaN
#        2021-06-28 09:54:49      NaN        NaN      NaN  1.000000      NaN
#        2021-06-28 09:55:59      NaN        NaN      NaN  0.986402      NaN
#        2021-06-28 09:57:10      NaN        NaN      NaN  0.974205      NaN
# ...                             ...        ...      ...       ...      ...
# 16137  2021-06-28 20:55:01      NaN        NaN      NaN  0.624043      NaN
#        2021-06-28 21:01:57      NaN        NaN      NaN       NaN      NaN
#        2021-06-28 21:11:57      NaN        NaN      NaN       NaN      NaN
#        2021-06-28 21:21:57      NaN        NaN      NaN       NaN      NaN
#        2021-06-28 21:31:57      NaN        NaN      NaN       NaN      NaN
#
#                               Volume      Feed
# run_id time
# 16130  2021-06-28 09:41:57  0.010000  0.000000
#        2021-06-28 09:53:38       NaN  0.000000
#        2021-06-28 09:54:49       NaN  0.000000
#        2021-06-28 09:55:59       NaN  0.000000
#        2021-06-28 09:57:10       NaN  0.000000
# ...                              ...       ...
# 16137  2021-06-28 20:55:01       NaN  0.000000
#        2021-06-28 21:01:57  0.009432  0.000021
#        2021-06-28 21:11:57       NaN  0.000021
#        2021-06-28 21:21:57       NaN  0.000021
#        2021-06-28 21:31:57       NaN  0.000021
#
# [5206 rows x 7 columns]
