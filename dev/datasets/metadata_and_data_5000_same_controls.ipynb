# %% [markdown]
# # Title

# %%
# %config InteractiveShell.ast_node_interactivity='last_expr_or_assign'  # always print last expr.
# %config InlineBackend.figure_format = 'svg'
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
import pickle

with open("metadata_and_data_5000_same_controls.pk", "rb") as file:
    data = pickle.load(file)

# %% [markdown]
# ### Format
# ```python
# data: tuple[dict('description': set[str], 'variables': list[dict[]], 'time_format': str, 'series': dict[int, dict['generating_parameters']]), dict[int, DataFrame]]
# ```

# %%
data[0]['series'][0]
# Out:
# {'generating_parameters': {'qsmax': 1.6536044101559502,
#   'qm': 0.01788833715522999,
#   'qamax': 1.4420104473680126,
#   'Yem': 0.5406616044074801,
#   'Yxsof': 0.35962393786179114,
#   'Yxa': 0.5436658818733858,
#   'Yos': 1.4828218577823062,
#   'Yoa': 1.0233298855079584,
#   'Yas': 0.27531777449631684,
#   'Kia': 1.1246103723391352,
#   'Ks': 0.11630542138390963,
#   'Ko': 1.6600855909569365,
#   'Kap': 0.3879293228005215,
#   'Kis': 2.5403011402469513,
#   'Ksa': 0.058369121879448364,
#   'Pamax': 0.19080098421622693,
#   'F0': 0.0087,
#   'mu_set': 0.222,
#   'C_feed': None,
#   'Kp': 80.21553353865144}}
