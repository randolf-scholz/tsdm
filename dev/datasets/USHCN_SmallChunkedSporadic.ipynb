# %% [markdown]
# # Title

# %%
# %config InteractiveShell.ast_node_interactivity='last_expr_or_assign'  # always print last expr.
# %config InlineBackend.figure_format = 'svg'
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import tsdm

ds = tsdm.datasets.USHCN_SmallChunkedSporadic
ds.dataset
# Out:
#           ID   Time  Value_0  Value_1  Value_2  Value_3   Value_4  Mask_0  \
# 0          0  180.3  -0.3057      0.0      0.0      0.0  0.000000    True
# 1          0  168.6  -0.3057      0.0      0.0      0.0  0.000000    True
# 2          0   31.4  -0.3057      0.0      0.0      0.0  0.000000    True
# 3          0    5.9  -0.3057      0.0      0.0      0.0  0.000000    True
# 4          0   32.6  -0.3057      0.0      0.0      0.0  0.000000    True
# ...      ...    ...      ...      ...      ...      ...       ...     ...
# 350660  1122  180.1   0.0000      0.0      0.0      0.0  0.719049   False
# 350661  1122   84.8   0.0000      0.0      0.0      0.0  0.197300   False
# 350662  1122  160.0   0.0000      0.0      0.0      0.0 -1.002722   False
# 350663  1122   25.8   0.0000      0.0      0.0      0.0  0.145125   False
# 350664  1122  156.9   0.0000      0.0      0.0      0.0 -1.263596   False
#
#         Mask_1  Mask_2  Mask_3  Mask_4
# 0        False   False   False   False
# 1        False   False   False   False
# 2        False   False   False   False
# 3        False   False   False   False
# 4        False   False   False   False
# ...        ...     ...     ...     ...
# 350660   False   False   False    True
# 350661   False   False   False    True
# 350662   False   False   False    True
# 350663   False   False   False    True
# 350664   False   False   False    True
#
# [350665 rows x 12 columns]

# %%
ds.dataset.mean()
# Out:
# ID         560.339127
# Time       100.340317
# Value_0      0.002439
# Value_1     -0.000168
# Value_2     -0.004020
# Value_3      0.000690
# Value_4      0.008692
# Mask_0       0.226253
# Mask_1       0.221585
# Mask_2       0.209830
# Mask_3       0.222914
# Mask_4       0.220378
# dtype: float64
