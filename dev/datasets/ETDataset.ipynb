# %%
# %config InteractiveShell.ast_node_interactivity='last_expr_or_assign'  # always print last expr.
# %config InlineBackend.figure_format = 'svg'
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

import logging
logging.basicConfig(level=logging.INFO)

# %%
from tsdm.datasets import ETT
from pandas import Timestamp, Timedelta, Period
# Out:
# INFO:numexpr.utils:Note: NumExpr detected 24 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# INFO:numexpr.utils:NumExpr defaulting to 8 threads.
# INFO:tsdm.config._config:Available Models: {'Latent-ODE', 'BRITS', 'NCDE', 'SET-TS', 'mTAN', 'IP-Net', 'GRU-ODE-Bayes', 'N-BEATS', 'TPA', 'ODE-RNN', 'Informer', 'TFT', 'NODE', 'M-RNN'}
# INFO:tsdm.config._config:Available Datasets: {'Air Quality', 'Physionet 2019', 'M4', 'M5', 'Traffic', 'Household Consumption', 'tourism2', 'USHCN', 'Electricity', 'Human Activity', 'tourism1', 'Physionet 2012', 'Air Quality Multi-Site', 'UWAVE', 'MuJoCo', 'M3', 'Character Trajectories'}
# INFO:tsdm.config._config:Initializing folder structure
# INFO:tsdm.config._config:creating folder /home/rscholz/.tsdm/datasets
# INFO:tsdm.config._config:creating folder /home/rscholz/.tsdm/models
# INFO:tsdm.config._config:creating folder /home/rscholz/.tsdm/logs
# INFO:tsdm.config._config:creating folder /home/rscholz/.tsdm/rawdata
# INFO:tsdm.config._config:Created folder structure in /home/rscholz/.tsdm
# WARNING:tsdm.datasets.ushcn:Using Modin with Ray Backend

# %%
ds = ETT(reset=True)
# Out:
# INFO:tsdm.datasets.base._base:ETT/None already exists, skipping.
# INFO:tsdm.datasets.base._base:ETT: START loading dataset!
# INFO:tsdm.datasets.base._base:ETT/ETTh1: START loading dataset!
# INFO:tsdm.datasets.base._base:ETT/ETTh1: DONE loading dataset!
# INFO:tsdm.datasets.base._base:ETT/ETTh2: START loading dataset!
# INFO:tsdm.datasets.base._base:ETT/ETTh2: DONE loading dataset!
# INFO:tsdm.datasets.base._base:ETT/ETTm1: START loading dataset!
# INFO:tsdm.datasets.base._base:ETT/ETTm1: DONE loading dataset!
# INFO:tsdm.datasets.base._base:ETT/ETTm2: START loading dataset!
# INFO:tsdm.datasets.base._base:ETT/ETTm2: DONE loading dataset!
# INFO:tsdm.datasets.base._base:ETT: DONE loading dataset!
# ETT['ETTh1', 'ETTh2', 'ETTm1', 'ETTm2']

# %%
ds.ETTh1
# Out:
#                        HUFL   HULL   MUFL   MULL   LUFL   LULL         OT
# date
# 2016-07-01 00:00:00   5.827  2.009  1.599  0.462  4.203  1.340  30.531000
# 2016-07-01 01:00:00   5.693  2.076  1.492  0.426  4.142  1.371  27.787001
# 2016-07-01 02:00:00   5.157  1.741  1.279  0.355  3.777  1.218  27.787001
# 2016-07-01 03:00:00   5.090  1.942  1.279  0.391  3.807  1.279  25.044001
# 2016-07-01 04:00:00   5.358  1.942  1.492  0.462  3.868  1.279  21.948000
# ...                     ...    ...    ...    ...    ...    ...        ...
# 2018-06-26 15:00:00  -1.674  3.550 -5.615  2.132  3.472  1.523  10.904000
# 2018-06-26 16:00:00  -5.492  4.287 -9.132  2.274  3.533  1.675  11.044000
# 2018-06-26 17:00:00   2.813  3.818 -0.817  2.097  3.716  1.523  10.271000
# 2018-06-26 18:00:00   9.243  3.818  5.472  2.097  3.655  1.432   9.778000
# 2018-06-26 19:00:00  10.114  3.550  6.183  1.564  3.716  1.462   9.567000
#
# [17420 rows x 7 columns]

# %%
dir(ds.rawdata_files["ETTh1"])
# Out:
# ['__bytes__',
#  '__class__',
#  '__class_getitem__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__enter__',
#  '__eq__',
#  '__exit__',
#  '__format__',
#  '__fspath__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rtruediv__',
#  '__setattr__',
#  '__sizeof__',
#  '__slots__',
#  '__str__',
#  '__subclasshook__',
#  '__truediv__',
#  '_accessor',
#  '_cached_cparts',
#  '_cparts',
#  '_drv',
#  '_flavour',
#  '_format_parsed_parts',
#  '_from_parsed_parts',
#  '_from_parts',
#  '_hash',
#  '_init',
#  '_make_child',
#  '_make_child_relpath',
#  '_opener',
#  '_parse_args',
#  '_parts',
#  '_pparts',
#  '_raw_open',
#  '_root',
#  '_str',
#  'absolute',
#  'anchor',
#  'as_posix',
#  'as_uri',
#  'chmod',
#  'cwd',
#  'drive',
#  'exists',
#  'expanduser',
#  'glob',
#  'group',
#  'home',
#  'is_absolute',
#  'is_block_device',
#  'is_char_device',
#  'is_dir',
#  'is_fifo',
#  'is_file',
#  'is_mount',
#  'is_relative_to',
#  'is_reserved',
#  'is_socket',
#  'is_symlink',
#  'iterdir',
#  'joinpath',
#  'lchmod',
#  'link_to',
#  'lstat',
#  'match',
#  'mkdir',
#  'name',
#  'open',
#  'owner',
#  'parent',
#  'parents',
#  'parts',
#  'read_bytes',
#  'read_text',
#  'readlink',
#  'relative_to',
#  'rename',
#  'replace',
#  'resolve',
#  'rglob',
#  'rmdir',
#  'root',
#  'samefile',
#  'stat',
#  'stem',
#  'suffix',
#  'suffixes',
#  'symlink_to',
#  'touch',
#  'unlink',
#  'with_name',
#  'with_stem',
#  'with_suffix',
#  'write_bytes',
#  'write_text']
