# %% [markdown]
# # Title

# %%
# %config InteractiveShell.ast_node_interactivity='last_expr_or_assign'  # always print last expr.
# %config InlineBackend.figure_format = 'svg'
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

import logging
logging.basicConfig(level=logging.INFO)

# %%
import numpy as np
import matplotlib.pyplot as plt

np.set_printoptions(precision=4, floatmode='fixed', suppress=True)
rng = np.random.default_rng()
# Out:
# Generator(PCG64) at 0x7F6E5054DBA0

# %%
import torch
from torch import jit, nn, Tensor
# Out:
# INFO:numexpr.utils:Note: NumExpr detected 24 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# INFO:numexpr.utils:NumExpr defaulting to 8 threads.

# %%
from typing import Any

# %%
class MyModule(nn.Module):
#     submodule: nn.Module
#     """This submodules purpose is to do X."""
    
    def __init__(self, **submodule_kwargs):
        super().__init__()
        self.submodule = nn.Identity(**submodule_kwargs)

# %%
jit.script( MyModule() )
# Out:
# RecursiveScriptModule(
#   original_name=MyModule
#   (submodule): RecursiveScriptModule(original_name=Identity)
# )
