# %%
from tsdm.datasets import Electricity, InSilicoData

# %%
list(InSilicoData.dataset.values())[0]
# Out:
#                      Biomass  Substrate  Acetate      DOTm  Product    Volume  \
# time
# 2021-06-28 09:41:57      NaN        NaN      NaN       NaN      NaN  0.010000
# 2021-06-28 09:53:38      NaN        NaN      NaN  0.983902      NaN       NaN
# 2021-06-28 09:54:49      NaN        NaN      NaN  1.000000      NaN       NaN
# 2021-06-28 09:55:59      NaN        NaN      NaN  0.986402      NaN       NaN
# 2021-06-28 09:57:10      NaN        NaN      NaN  0.974205      NaN       NaN
# ...                      ...        ...      ...       ...      ...       ...
# 2021-06-28 20:55:01      NaN        NaN      NaN  0.651887      NaN       NaN
# 2021-06-28 21:01:57      NaN        NaN      NaN       NaN      NaN  0.009797
# 2021-06-28 21:11:57      NaN        NaN      NaN       NaN      NaN  0.009810
# 2021-06-28 21:21:57      NaN        NaN      NaN       NaN      NaN       NaN
# 2021-06-28 21:31:57      NaN        NaN      NaN       NaN      NaN       NaN
#
# ...
